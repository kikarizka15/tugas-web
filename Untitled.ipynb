# %%
Definisi 1.1.1. Persamaan Linier
Sebuah ekspresi linier dalam ( n ) peubah (atau variabel) ( x_1, x_2, \dots, x_n ) adalah suatu ekspresi berbentuk:

[ a_1 x_1 + a_2 x_2 + \cdots + a_n x_n, ]

di mana ( a_1, a_2, \dots, a_n ) adalah bilangan real tetap.

Sebuah persamaan linier dalam peubah ( x_1, x_2, \dots, x_n ) adalah persamaan yang dapat disederhanakan, hanya dengan menggunakan operasi penjumlahan dan pengurangan, menjadi persamaan berbentuk:

[ a_1 x_1 + a_2 x_2 + \cdots + a_n x_n = b, \tag{1.1.1} ]

yang disebut sebagai bentuk standar.

Suatu persamaan dalam peubah ( x_1, x_2, \dots, x_n ) disebut nonlinier jika tidak dapat disederhanakan ke bentuk (1.1.1) hanya dengan menggunakan penjumlahan dan pengurangan.

Diberikan persamaan linier dalam bentuk standar (1.1.1), persamaan tersebut disebut:

homogen jika ( b = 0 ),
tak homogen (nonhomogen) jika ( b \ne 0 ).
# Out:
#   Cell In[3], line 1
#     Definisi 1.1.1. Persamaan Linier
#              ^
# SyntaxError: invalid syntax
